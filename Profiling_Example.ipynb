# %%
# Install a specific version of the package(Pandas-profiling)
import pandas as pd
import pandas_profiling

# %%
# Make sure to load the file( ListA.txt) to your Colab notebook
df_list_a = pd.read_csv("/content/sample_data/ListA.txt", sep= '\t')

# %%
# Display the top 10 records of the dataset
df_list_a .head(10)
# Out:
#      recid    fname    lname      mname                    address  \
# 0  A848132        A     HYRE    NICHOLE             4749 audrey dr
# 1  A848133      NaN  HONDROS          K            1225 WATSON AVE
# 2  A848134  KENNETH   CORBIN      LEROY     2426 E ONYX TRL  APT 3
# 3  A848135      NaN   FREIDA        NaN        625 RUNNINGBROOK LN
# 4  A848136      NaN  FLEMING          G  14272  HOOVER ST  TRLR 38
# 5  A848137     JORY  HARRELL        NaN    1620 TRINITY GARDEN CIR
# 6  A848138        B   GORDON      MCCOY      5205 MERELEDGE CT # J
# 7  A848139   Twanna   Fuller     Denise         434 VALLEYMEADE DR
# 8  A848140   CLAUDE  KENNEDY          R            1763 LATONIA RD
# 9  A848141     MARY     DULA  ELIZABETH               5412 MESA CT
#
#             city state      zip          ssn       homephone
# 0  winston salem    nc  27127.0  337-80-1789  (834)-289-5647
# 1  WINSTON SALEM    NC  27103.0          NaN    (541)7124583
# ...

# %%
# Display the last 10 records of the dataset
df_list_a .tail(10)
# Out:
#           recid    fname      lname    mname                      address  \
# 151858  A999990   BRENDA    JACKSON      NaN             1317 E SECOND ST
# 151859  A999991    TANIA      BROWN  SHICOLE               129 W LEMLY ST
# 151860  A999992      NaN     HAUSER        A                319 S MAIN ST
# 151861  A999993  TIMOTHY  HUNSUCKER        W             215 GRANDVIEW DR
# 151862  A999994      NaN    HOLCOMB    ALVIN       195 WILLOW BEND CT # J
# 151863  A999995   KERRIN    JARRELL    LURAE           1664 RIDGESTONE LN
# 151864  A999996  BRANDON    AMBROSE    HEATH  5280 CAMP BETTY HASTINGS RD
# 151865  A999997      NaN    CLINARD    SHAWN        4777 VIENNA DOZIER RD
# 151866  A999998    JAMES    ALLISON   GERALD              1305 WOODLYN ST
# 151867  A999999   ROBERT      BUYNA      NaN   6508 lagrande place dr # 4
#
#                  city state      zip          ssn       homephone
# 151858  WINSTON SALEM    NC  27101.0  435-41-4611  (258)-721-8679
# ...

# %%
# What is the shape of the dataset - Total rows and columns
df_list_a .shape
# Out:
# (151868, 10)

# %%
# Select records(rows) from “AR” which are having “fname” and “ssn” not missing/not blank
df_list_a[(df_list_a.state=="AR")&(df_list_a.fname.notnull())&(df_list_a.ssn.notnull())]
# Out:
#           recid      fname      lname     mname                     address  \
# 2       A848134    KENNETH     CORBIN     LEROY      2426 E ONYX TRL  APT 3
# 187     A848319     Steven      Jolly    Lamont        131  MILLBROOK ST
# 607     A848739     RACHEL      BYYRD       NaN            510  QUAIL ST
# 762     A848894      ANNIE    BRADLEY       MAE   1650  GREENE ROAD 847
# 1187    A849319      James   Campbell       NaN  1501 NE DYSART WOODS LN
# ...         ...        ...        ...       ...                         ...
# 150590  A998722    MICHAEL  KETTERING         D      2810  LOVE CREEK DR
# 151419  A999551      Sarah    Caroway  Callahan       348  BRADLEY 33 RD
# 151420  A999552  JOONATHAN     HAYNES       RAY      425  POLK ROAD 136
# 151570  A999702      BRUCE     CARTER       NaN           25  ROLLING LN
# 151843  A999975     STEVEN   GLEDHILL      FRED           267  GILMER LN
#
#                              city state      zip          ssn       homephone
# ...

# %%
# Sort records(row) by “fname”
df_list_a.sort_values(['fname'], ascending=True)
# Out:
#           recid fname      lname    mname                 address  \
# 0       A848132     A       HYRE  NICHOLE          4749 audrey dr
# 116075  A964207     A      HONEY      CON    3482 TANGLEBROOK TRL
# 32092   A880224     A       GWYN      NaN         4420 KIMBALL LN
# 56244   A904376     A     HOBACK      MAE           107 DILLON ST
# 80344   A928476     A  CERECERES   MARCUS      813 CROOKED RUN RD
# ...         ...   ...        ...      ...                     ...
# 151852  A999984   NaN      JONES        M     5060 LAKE GARDEN CT
# 151856  A999988   NaN      JONES        W      3534 FIELDSTONE DR
# 151860  A999992   NaN     HAUSER        A           319 S MAIN ST
# 151862  A999994   NaN    HOLCOMB    ALVIN  195 WILLOW BEND CT # J
# 151865  A999997   NaN    CLINARD    SHAWN   4777 VIENNA DOZIER RD
#
#                  city state      zip          ssn       homephone
# 0       winston salem    nc  27127.0  337-80-1789  (834)-289-5647
# ...

# %%
# Generate the profiling report
profile_list_a = pandas_profiling.ProfileReport(df_list_a)
profile_list_a
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.4.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/pandas-profiling&gt;&lt;meta name=date content=&quot;2022-11-19 21:29:12.027761&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
# Save as an html file. The file should be in the Files section on Colab.
profile_list_a.to_file('list_a.html')
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
